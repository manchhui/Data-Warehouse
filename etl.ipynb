# %% [markdown]
# # Parallel ETL

# %%
from time import time
import psycopg2
import configparser
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## STEP 1: Get the params of the created redshift cluster

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh_crshc.cfg'))
KEY=config.get('AWS','key')
SECRET= config.get('AWS','secret')

DWH_DB= config.get("DWH","DWH_DB")
DWH_DB_USER= config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD= config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT = config.get("DWH","DWH_PORT")

# %%
# FILL IN THE REDSHIFT ENPOINT HERE
# e.g. DWH_ENDPOINT="redshift-cluster-1.csmamz5zxmle.us-west-2.redshift.amazonaws.com" 
DWH_ENDPOINT="dwhcluster.ckoszxyq4rgx.us-west-2.redshift.amazonaws.com" 
    
#FILL IN THE IAM ROLE ARN you got in step 2.2 of the previous exercise
#e.g DWH_ROLE_ARN="arn:aws:iam::988332130976:role/dwhRole"
#DWH_ROLE_ARN="arn:aws:iam::220621774524:role/dwhRole"
DWH_ROLE_ARN= config.get("IAM_ROLE","ARN")

# %% [markdown]
# ## STEP 2: Connect to the Redshift Cluster

# %%
# %%time
conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(DWH_ENDPOINT, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT))
cur = conn.cursor()
print(conn)
# Out:
# <connection object at 0x7fcd854122a8; dsn: 'user=dwhuser password=xxx dbname=dwh host=dwhcluster.ckoszxyq4rgx.us-west-2.redshift.amazonaws.com port=5439', closed: 0>
# CPU times: user 1.66 ms, sys: 3.62 ms, total: 5.27 ms
# Wall time: 431 ms

# %%
import boto3

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                     )

sampleDbBucket =  s3.Bucket("udacity-dend")

for obj in sampleDbBucket.objects.filter(Prefix="log"):
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-01-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-02-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-03-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-04-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-05-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-06-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-07-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-08-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-09-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-10-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-11-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-12-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-13-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-14-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-15-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-16-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-17-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-18-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-19-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-20-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-21-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-22-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-23-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-24-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-25-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-26-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-27-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-28-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-29-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-30-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-01-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-02-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-03-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-04-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-05-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-06-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-07-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-08-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-09-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-10-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-11-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-12-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-13-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-14-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-15-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-16-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-17-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-18-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-19-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-20-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-21-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-22-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-23-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-24-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-25-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-26-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-27-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-28-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-29-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-30-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_json_path.json')

# %% [markdown]
# ## STEP 3: Create Staging Tables

# %%
# %%time
cur.execute("""
DROP TABLE IF EXISTS "staging_logs"; 
DROP TABLE IF EXISTS "staging_songs"; 
CREATE TABLE "staging_logs" ("artist" varchar,
                             "auth" varchar,
                             "firstName" varchar,
                             "gender" varchar,
                             "itemInSession" varchar,
                             "lastName" varchar,
                             "length" float,
                             "level" varchar,
                             "location" varchar,
                             "method" varchar,
                             "page" varchar,
                             "registration" float,
                             "sessionId" int,
                             "song" varchar,
                             "status" varchar,
                             "ts" bigint,
                             "userAgent" varchar,
                             "userId" int);


CREATE TABLE IF NOT EXISTS "staging_songs" ("artist_id" varchar,
                                            "artist_latitude" real,
                                            "artist_location" varchar,
                                            "artist_longitude" real,
                                            "artist_name" varchar,
                                            "duration" float,
                                            "num_songs" int,
                                            "song_id" varchar,
                                            "title" varchar,
                                            "year" int);
""");
# Out:
# CPU times: user 0 ns, sys: 1.38 ms, total: 1.38 ms
# Wall time: 126 ms

# %% [markdown]
# ## STEP 4: Copy S3 Data To Staging

# %%
# %%time
cur.execute("""
copy staging_logs 
from 's3://udacity-dend/log_data' 
credentials 'aws_iam_role={}'
format as json 's3://udacity-dend/log_json_path.json'
compupdate off
emptyasnull
blanksasnull
region 'us-west-2';
""".format(DWH_ROLE_ARN))
# Out:
# CPU times: user 1.41 ms, sys: 233 µs, total: 1.64 ms
# Wall time: 629 ms

# %%
# %%time
cur.execute("""
copy staging_songs 
from 's3://udacity-dend/song_data' 
credentials 'aws_iam_role={}'
format as json 'auto'
compupdate off
emptyasnull
blanksasnull
region 'us-west-2';
""".format(DWH_ROLE_ARN))
# Out:
# CPU times: user 1.83 ms, sys: 303 µs, total: 2.14 ms
# Wall time: 1min 36s

# %%
cur.execute("""DELETE FROM staging_logs WHERE userId IS NULL;""")
cur.execute("""DELETE FROM staging_logs WHERE sessionId IS NULL;""")
cur.execute("""DELETE FROM staging_logs WHERE ts IS NULL;""")
cur.execute("""DELETE FROM staging_songs WHERE song_id IS NULL;""")
cur.execute("""DELETE FROM staging_songs WHERE artist_id IS NULL;""")
conn.commit()

# %% [markdown]
# ## STEP 5: Create Tables for Star Schema DB

# %%
# %%time
cur.execute("""
DROP TABLE IF EXISTS "songplays";
DROP TABLE IF EXISTS "users";
DROP TABLE IF EXISTS "songs";
DROP TABLE IF EXISTS "artist";
DROP TABLE IF EXISTS "time";

CREATE TABLE IF NOT EXISTS "users" ("user_id" int NOT NULL,
                                    "first_name" varchar,
                                    "last_name" varchar,
                                    "gender" varchar(1),
                                    "level" varchar(4),
                                    PRIMARY KEY ("user_id"));

CREATE TABLE IF NOT EXISTS "songs" ("song_id" varchar NOT NULL,
                                    "title" varchar,
                                    "artist_id" varchar,
                                    "year" int,
                                    "duration" float,
                                    PRIMARY KEY ("song_id"));

CREATE TABLE IF NOT EXISTS "artists" ("artist_id" varchar NOT NULL,
                                      "name" varchar,
                                      "location" varchar,
                                      "latitude" real,
                                      "longitude" real,
                                      PRIMARY KEY ("artist_id"));

CREATE TABLE IF NOT EXISTS "time" ("start_time" timestamp NOT NULL,
                                   "hour" int,
                                   "day" int,
                                   "week" int,
                                   "month" int,
                                   "year" int,
                                   "weekday" int,
                                   PRIMARY KEY ("start_time"));

CREATE TABLE IF NOT EXISTS songplays (songplay_id bigint NOT NULL, 
                                        start_time timestamp NOT NULL,
                                        user_id int NOT NULL,
                                        level varchar(4) NOT NULL,
                                        song_id varchar,
                                        artist_id varchar,
                                        session_id int NOT NULL,
                                        location varchar NOT NULL,
                                        user_agent varchar NOT NULL,
                                        PRIMARY KEY (songplay_id),
                                        FOREIGN KEY (song_id) REFERENCES songs (song_id),
                                        FOREIGN KEY (artist_id) REFERENCES artists (artist_id),
                                        FOREIGN KEY (start_time) REFERENCES time (start_time),
                                        FOREIGN KEY (user_id) REFERENCES users (user_id),
                                        UNIQUE (start_time, user_id, session_id));
""")
conn.commit()
# Out:
# CPU times: user 921 µs, sys: 141 µs, total: 1.06 ms
# Wall time: 258 ms

# %% [markdown]
# # STEP 5: Load data into the cluster

# %%
# %%time
#Load Users Table
cur.execute("""
CREATE TABLE IF NOT EXISTS "users_staging" ("user_id" int NOT NULL,
                                    "first_name" varchar,
                                    "last_name" varchar,
                                    "gender" varchar(1),
                                    "level" varchar(4),
                                    "start_time" bigint,
                                    PRIMARY KEY ("user_id"));

INSERT INTO users_staging 
    SELECT DISTINCT 
        CAST(userId AS int) AS user_id, 
        firstName AS first_name, 
        lastName AS last_name, 
        gender, 
        level,
        ts AS "start_time"
FROM staging_logs;

INSERT INTO users 
    SELECT st.user_id, st.first_name, st.last_name, st.gender, st.level
FROM (SELECT st.*,
             ROW_NUMBER() OVER (PARTITION BY user_id ORDER BY start_time DESC) seqnum
      FROM users_staging st) st
LEFT JOIN users u
ON st.user_id = u.user_id
WHERE seqnum = 1 AND u.user_id IS NULL;

UPDATE users
SET level = st.level
FROM (SELECT st.*,
                ROW_NUMBER() OVER (PARTITION BY user_id ORDER BY start_time DESC) seqnum
        FROM users_staging st) st
JOIN users u
ON st.user_id = u.user_id
WHERE seqnum = 1 
AND (u.user_id = st.user_id AND u.first_name = st.first_name AND u.last_name = st.last_name AND u.gender = st.gender AND u.level <> st.level);
""")
conn.commit()
# Out:
# CPU times: user 869 µs, sys: 134 µs, total: 1 ms
# Wall time: 760 ms

# %%
# %%time
#Load Song Table
cur.execute("""
CREATE TEMP TABLE songs_staging (LIKE songs);

INSERT INTO songs_staging 
    SELECT DISTINCT song_id, title, artist_id, year, duration
FROM staging_songs;

INSERT INTO songs 
    SELECT st.song_id, st.title, st.artist_id, st.year, st.duration
FROM (SELECT st.*,
             ROW_NUMBER() OVER (PARTITION BY song_id, title, artist_id, year, duration ORDER BY song_id, title, artist_id, year, duration DESC) seqnum
      FROM songs_staging st) st
LEFT JOIN songs s
ON st.song_id = s.song_id
WHERE seqnum = 1 AND s.song_id IS NULL;   

DROP TABLE songs_staging;
""")
conn.commit()
# Out:
# CPU times: user 1.55 ms, sys: 239 µs, total: 1.79 ms
# Wall time: 550 ms

# %%
# %%time
#Load Artists Table
cur.execute("""
CREATE TEMP TABLE artists_staging (LIKE artists);

INSERT INTO artists_staging 
    SELECT DISTINCT 
        artist_id, 
        artist_name AS name, 
        artist_location AS location, 
        artist_latitude AS latitude, 
        artist_longitude AS longitude
FROM staging_songs;

INSERT INTO artists 
    SELECT st.artist_id, st.name, st.location, st.latitude, st.longitude
FROM (SELECT st.*,
             ROW_NUMBER() OVER (PARTITION BY artist_id, name, location, latitude, longitude ORDER BY artist_id, name, location, latitude, longitude DESC) seqnum
      FROM artists_staging st) st
LEFT JOIN artists a
ON st.artist_id = a.artist_id
WHERE seqnum = 1 AND a.artist_id IS NULL;    

DROP TABLE artists_staging;
""")
conn.commit()
# Out:
# CPU times: user 1.67 ms, sys: 0 ns, total: 1.67 ms
# Wall time: 388 ms

# %%
# %%time
#Load Time Table
cur.execute("""
CREATE TEMP TABLE time_staging (LIKE time);

INSERT INTO time_staging 
    SELECT DISTINCT 
        DATEADD(ms, ts,'1970-1-1') AS start_time, 
        DATE_PART(hour, DATEADD(ms, ts,'1970-1-1')) AS hour, 
        DATE_PART(day, DATEADD(ms, ts,'1970-1-1')) AS day, 
        DATE_PART(week, DATEADD(ms, ts,'1970-1-1')) AS week, 
        DATE_PART(month, DATEADD(ms, ts,'1970-1-1')) AS month, 
        DATE_PART(year, DATEADD(ms, ts,'1970-1-1')) AS year, 
        DATE_PART(weekday, DATEADD(ms, ts,'1970-1-1')) AS weekday
FROM staging_logs;

INSERT INTO time 
    SELECT st.start_time, st.hour, st.week, st.month, st.year, st.weekday
FROM (SELECT st.*,
             ROW_NUMBER() OVER (PARTITION BY start_time ORDER BY start_time DESC) seqnum
      FROM time_staging st) st
LEFT JOIN time t
ON st.start_time = t.start_time
WHERE seqnum = 1 AND t.start_time IS NULL;

DROP TABLE time_staging;
""")
conn.commit()
# Out:
# CPU times: user 0 ns, sys: 1.95 ms, total: 1.95 ms
# Wall time: 569 ms

# %%
# %%time
#Load Songplays Table
cur.execute("""
CREATE TEMP TABLE songplays_staging (songplay_id bigint NOT NULL, 
                                        start_time timestamp NOT NULL,
                                        user_id int NOT NULL,
                                        level varchar(4) NOT NULL,
                                        song_id varchar,
                                        artist_id varchar,
                                        session_id int NOT NULL,
                                        location varchar NOT NULL,
                                        user_agent varchar NOT NULL,
                                        song varchar,
                                        artist varchar,
                                        length float,
                                        ts bigint,
                                        concat_id varchar NOT NULL);

CREATE TEMP TABLE songplays_staging1 (song_id varchar NOT NULL,
                                        song varchar NOT NULL,
                                        artist_id varchar NOT NULL,
                                        artist varchar NOT NULL,
                                        length float NOT NULL,
                                        concat_id varchar NOT NULL);
                                        
INSERT INTO songplays_staging
SELECT DISTINCT
    1, 
    DATEADD(ms, ts,'1970-1-1') AS start_time, 
    userid AS user_id, 
    level, 
    'None', 
    'None', 
    sessionid AS session_id, 
    location, 
    useragent AS user_agent,
    song,
    artist,
    length,
    ts,
    'None'
FROM staging_logs;

UPDATE songplays_staging
SET concat_id = song || artist || CAST(length AS text)
WHERE (song || artist || CAST(length AS text)) IS NOT NULL;

INSERT INTO songplays_staging1
SELECT 
    s.song_id, 
    s.title AS song, 
    a.artist_id, 
    a.name AS artist, 
    s.duration AS length,
    (SELECT song || artist || CAST(length AS text)) AS concat_id
FROM songs s 
JOIN artists a ON s.artist_id = a.artist_id;

UPDATE songplays_staging
SET song_id = st1.song_id,
    artist_id = st1.artist_id
FROM songplays_staging st
    JOIN songplays_staging1 st1
        ON st.concat_id = st1.concat_id;
        
INSERT INTO songplays 
SELECT CAST((ROW_NUMBER() OVER (ORDER BY st.ts) || st.ts) AS bigint) AS songplay_id, 
    st.start_time, 
    st.user_id, 
    st.level, 
    st.song_id, 
    st.artist_id, 
    st.session_id, 
    st.location, 
    st.user_agent
FROM (SELECT st.*,
             ROW_NUMBER() OVER (PARTITION BY ts, 
                                             user_id, 
                                             level, 
                                             song_id, 
                                             artist_id, 
                                             location, 
                                             song, 
                                             artist, 
                                             length,
                                             user_agent ORDER BY ts, 
                                                             user_id, 
                                                             level, 
                                                             song_id, 
                                                             artist_id, 
                                                             location, 
                                                             song, 
                                                             artist, 
                                                             length,
                                                             user_agent DESC) seqnum
      FROM songplays_staging st) st
LEFT JOIN songplays s
ON st.songplay_id = s.songplay_id
WHERE seqnum = 1 AND s.songplay_id IS NULL;

DROP TABLE IF EXISTS songplays_staging;
DROP TABLE IF EXISTS songplays_staging1;
""")
conn.commit()
# Out:
# CPU times: user 653 µs, sys: 100 µs, total: 753 µs
# Wall time: 6.41 s

# %%
# %%time
#Load Songplays Table
cur.execute("""
DROP TABLE IF EXISTS songplays_staging;
DROP TABLE IF EXISTS songplays_staging1;
DROP TABLE artists_staging;
""")
conn.commit()
# Out:
# CPU times: user 1.65 ms, sys: 0 ns, total: 1.65 ms
# Wall time: 170 ms

# %%
conn.commit()

# %%
# %%time
cur.execute("SELECT * FROM artists;")
colnames = [desc[0] for desc in cur.description]
colnames
    
# extract data from staging_logs file
cur.execute("SELECT * FROM artists;")
data=cur.fetchall()
    
# create dataframe
df_test = pd.DataFrame(data,columns=colnames)
# Out:
# CPU times: user 31.9 ms, sys: 7.73 ms, total: 39.6 ms
# Wall time: 3.79 s

# %%
df_test
# Out:
#                 artist_id                                              name  \
# 0      AR00B1I1187FB433EB                                  Eagle-Eye Cherry
# 1      AR00DG71187B9B7FCB                                 Basslovers United
# 2      AR00FVC1187FB5BE3E                                             Panda
# 3      AR00JIO1187B9A5A15                                            Saigon
# 4      AR00LNI1187FB444A5                                      Bruce BecVar
# 5      AR00MQ31187B9ACD8F                                     Chris Carrier
# 6      AR00TGQ1187B994F29                                      Paula Toller
# 7      AR00Y9I1187B999412                                         Akercocke
# 8      AR00YYQ1187FB504DC                                God Is My Co-Pilot
# 9      AR016P51187B98E398                                    Indian Ropeman
# 10     AR01G6G1187B9892EF                                   Tonino Carotone
# 11     AR01IP11187B9AF5D2                                  Call To Preserve
# 12     AR01S3D1187FB50A53                                      Charlie Parr
# 13     AR01SCU1187B9A693C                                       Street Dogs
# 14     AR01WHF1187B9B53B8                                         Lullatone
# 15     AR026BB1187B994DC3                                      Ijahman Levi
# 16     AR026PU1187FB43FD9                                        The Vapors
# 17     AR02IU11187FB513F2                                       Tito Puente
# 18     AR02LMQ1187B992AC9                                 The Classic Crime
# 19     AR02T3I1187FB4D0E5                                         Aberfeldy
# 20     AR02YGA1187B9B8AC4                                Bersuit Vergarabat
# 21     AR035N21187FB3938E                                                BT
# 22     AR039B11187B9B30D0                                     John Williams
# 23     AR03BDP1187FB5B324                                    Britney Spears
# 24     AR03BDP1187FB5B324            Britney Spears feat. Pharrell Williams
# 25     AR03ESE1187B992BC5                                        Bon Voyage
# 26     AR03IZC1187FB3E058                                           Aidonia
# 27     AR03P141187B9B8CE6                                     Teo Mammucari
# 28     AR03Z7E1187FB44816         The Colourfield Featuring Sinead O'Connor
# 29     AR040JZ1187FB399A9                                            Sparks
# ...                   ...                                               ...
# 9995   ARZW4IM1187B9B6565                                     Governor Andy
# 9996   ARZWAHK119B8668273                                         Martriden
# 9997   ARZWGAI11E2835CFCE                                          Laki Lan
# 9998   ARZWIZL1187B9B3409                                  Element Of Crime
# 9999   ARZWK2R1187B98F09F                                      Rise Against
# 10000  ARZWN6W1187FB3EF25                                      Company Flow
# 10001  ARZWPWP1241B9CA793                                     Henry Mancini
# 10002  ARZWWI41187FB3F104                                           Taktika
# 10003  ARZXC9Y1187FB57133                              Afro-Cuban All Stars
# 10004  ARZXLZD11E2835CEA7                             Jason Michael Carroll
# 10005  ARZXNFV1187B9BA2CD                                         Buddy Guy
# 10006  ARZXTEY1187B9997A7                                     Juelz Santana
# 10007  ARZXTEY1187B9997A7                             Juelz Santana / Bezel
# 10008  ARZXTEY1187B9997A7  Juelz Santana / Freekey Zeekey / Monique Garnett
# 10009  ARZXVCV1187FB3DD66                                     Vicente Amigo
# 10010  ARZXYRK1187B99E432                                      John Stevens
# 10011  ARZY3LW1187B9BA45A                                        Lee Morgan
# 10012  ARZYJO61187B98F4B9                                              Stoa
# 10013  ARZYMH91187B99CEFC                                        Atmosphere
# 10014  ARZYP6O1187B9892E7  Chapta_ Stage McCloud_ SupaStarr & Tony Manshino
# 10015  ARZYPLF1187FB45B9B                                            Rooney
# 10016  ARZYRP21187FB53526                                           Bedhead
# 10017  ARZYSCW1187FB52DF7                                      Marcos Valle
# 10018  ARZYZUU11F4C841DCC                            Gatsbys American Dream
# 10019  ARZZ5ZR1187FB4D149                                               Air
# 10020  ARZZMWO1187B9AFB36                                      Brutal Truth
# 10021  ARZZOM61187FB3942C                                   Augustus Clarke
# 10022  ARZZQZQ12509411C96                                  Francis Magalona
# 10023  ARZZRK91187B9A5CA5                                     Delroy Wilson
# 10024  ARZZXT51187FB4627E         Julie Driscoll_ Brian Auger & The Trinity
#
#                             location  latitude  longitude
# 0                  Stockholm, Sweden       NaN        NaN
# 1                               None       NaN        NaN
# 2              Monterrey, NL, México  25.67084 -100.30953
# 3                           Brooklyn  40.65507  -73.94888
# 4                               None       NaN        NaN
# 5                               None       NaN        NaN
# 6                               None       NaN        NaN
# 7                               None       NaN        NaN
# 8                       New York, NY  40.71455  -74.00712
# 9                               None       NaN        NaN
# 10                              None       NaN        NaN
# 11                Rockledge, Florida  28.33268  -80.73486
# 12                         Minnesota       NaN        NaN
# 13                        Boston, MA       NaN        NaN
# 14                     Nagoya, Japan       NaN        NaN
# 15                              None       NaN        NaN
# 16                              None       NaN        NaN
# 17                      New York, NY       NaN        NaN
# 18                       Seattle, WA  47.60356 -122.32944
# 19               Edinburgh, Scotland       NaN        NaN
# 20                      Buenos Aires -34.60852  -58.37354
# 21                             Earth  34.23294 -102.41020
# 22                NEW YORK, New York       NaN        NaN
# 23     Kentwood, LA; Los Angeles, CA  34.05349 -118.24532
# 24     Kentwood, LA; Los Angeles, CA  34.05349 -118.24532
# 25                              None       NaN        NaN
# 26                              None       NaN        NaN
# 27                              None       NaN        NaN
# 28               Manchester, England  53.47960   -2.24881
# 29                   Los Angeles, CA  34.05349 -118.24532
# ...                              ...       ...        ...
# 9995                            None       NaN        NaN
# 9996                       Havre, MT  48.55286 -109.67097
# 9997                            None       NaN        NaN
# 9998            West Berlin, Germany  52.51607   13.37698
# 9999                         Chicago       NaN        NaN
# 10000                       brooklyn  40.65507  -73.94888
# 10001                  Cleveland, OH       NaN        NaN
# 10002                           None       NaN        NaN
# 10003                           None       NaN        NaN
# 10004                           None       NaN        NaN
# 10005                 Lettsworth, LA       NaN        NaN
# 10006          New York, NY [Harlem]       NaN        NaN
# 10007          New York, NY [Harlem]       NaN        NaN
# 10008          New York, NY [Harlem]       NaN        NaN
# 10009                           None       NaN        NaN
# 10010                         Madrid       NaN        NaN
# 10011               Philadelphia, PA  39.95227  -75.16237
# 10012                           None       NaN        NaN
# 10013                Minneapolis, MN  44.97903  -93.26493
# 10014                           None       NaN        NaN
# 10015                Los Angeles, CA  34.05349 -118.24532
# 10016                     Dallas, TX       NaN        NaN
# 10017         Rio de Janeiro, Brazil -22.97673  -43.19508
# 10018                    Seattle, WA       NaN        NaN
# 10019                  United States       NaN        NaN
# 10020                   New York, NY  40.71455  -74.00712
# 10021                           None       NaN        NaN
# 10022                           None       NaN        NaN
# 10023              Kingston, Jamaica  18.01571  -76.79731
# 10024                           None       NaN        NaN
#
# [10025 rows x 5 columns]

# %%
conn.commit()
